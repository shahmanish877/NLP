# %% [markdown]
# # Application of NLP: Spell Checker
#
# Spell checkers can use `approximate string matching algorithms` such as `Levenshtein distance`, `jaccard distance` to find correct spellings of misspelled words
#
# Understanding the Levenshtein Distance Equation for Beginners
# https://medium.com/@ethannam/understanding-the-levenshtein-distance-equation-for-beginners-c4285a5604f0

# %%
import nltk
from nltk.corpus import words

# load the dictionary
nltk.download('words')
correct_words = words.words()
# len(correct_words) # 236736 words
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %% [markdown]
# ## Using Jaccard distance Method

# %%
# importing jaccard distance and ngrams from nltk.util
from nltk.metrics.distance import jaccard_distance
from nltk.util import ngrams

# %%
# list of incorrect spellings
# that need to be corrected
incorrect_words = ['happpy', 'azmaing', 'intelliengt']

# loop for finding correct spellings
# based on jaccard distance
# and printing the correct word
for word in incorrect_words:
    temp = [(jaccard_distance(set(ngrams(word, 2)), set(ngrams(w, 2))),w) for w in correct_words if w[0] == word[0]]
    print(sorted(temp, key = lambda val:val[0])[0][1])
# Out:
# happy
# amazing
# intelligent

# %%
set(ngrams(word, 2))
# Out:
# {('e', 'l'),
#  ('e', 'n'),
#  ('g', 't'),
#  ('i', 'e'),
#  ('i', 'n'),
#  ('l', 'i'),
#  ('l', 'l'),
#  ('n', 'g'),
#  ('n', 't'),
#  ('t', 'e')}

# %% [markdown]
# ## Using Edit distance Method
# Edit Distance measures dissimilarity between two strings by finding the minimum number of operations needed to transform one string into the other.
# The transformations that can be performed are:
#
# - Inserting a new character: `bat -> bats (insertion of 's')`
# - Deleting an existing character : `care -> car (deletion of 'e')`
# - Substituting an existing character: `bin -> bit (substitution of n with t)`
# - Transposition of two existing consecutive characters: `sing -> sign (transposition of ng to gn)`

# %%
import nltk
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
from nltk.metrics.distance  import edit_distance
from nltk.corpus import words
correct_words = words.words()

incorrect_words=['happpy', 'azmaing', 'intelliengt']

# loop for finding correct spellings
# based on edit distance and
# printing the correct words
for word in incorrect_words:
    temp = [(edit_distance(word, w),w) for w in correct_words if w[0]==word[0]]
    print(sorted(temp))
    # print(sorted(temp, key = lambda val:val[0])[0][1])
# Out:
# [(1, 'happy'), (1, 'happy'), (2, 'haply'), (2, 'happen'), (2, 'happify'), (2, 'happily'), (2, 'hippy'), (2, 'hoppy'), (3, 'hackly'), (3, 'hacky'), (3, 'haggly'), (3, 'haggy'), (3, 'haily'), (3, 'hairy'), (3, 'hammy'), (3, 'hamper'), (3, 'handy'), (3, 'hangby'), (3, 'hanky'), (3, 'hap'), (3, 'happier'), (3, 'happing'), (3, 'hapten'), (3, 'haptic'), (3, 'hapu'), (3, 'hapuku'), (3, 'hardly'), (3, 'hardy'), (3, 'harp'), (3, 'harper'), (3, 'harry'), (3, 'hashy'), (3, 'hasky'), (3, 'hasp'), (3, 'hasty'), (3, 'hatpin'), (3, 'hatty'), (3, 'haulmy'), (3, 'haunty'), (3, 'hawky'), (3, 'hay'), (3, 'hayey'), (3, 'hazily'), (3, 'hazy'), (3, 'heapy'), (3
), (5, 'intention'), (5, 'intentional'), (5, 'intentioned'), (5, 'interagency'), (5, 'interallied'), (5, 'interblend'), (5, 'interbring'), (5, 'intercadent'), (5, 'intercept'), (5, 'interchange'), (5, 'interdict'), (5, 'interdine'), (5, 'intereat'), (5, 'interest'), (5, 'interest'), (5, 'interferent'), (5, 'interfinger'), (5, 'interflange'), (5, 'interfluence'), (5, 'interfret'), (5, 'interfulgent'), (5, 'intergilt'), (5, 'interimist'), (5, 'interionic'), (5, 'interjacent'), (5, 'interject'), (5, 'interknit'), (5, 'interknot'), (5, 'interleaf'), (5, 'interleague'), (5, 'interleave'), (5, 'interlibel'), (5, 'interlineal'), (5, 'interlinear'), (5, 'interlineary'), (5, 'interlineate'), (5, 'interlinement'), (5, 'interlingual'), (5, 'interlinguist'), (5, 'interloan'), (5, 'interlot'), (5, 'interlunar'), (5, 'intermeet'), (5, 'intermelt'), (5, 'interminant'), (5, 'interminate'), (5, 'intermine'), (5, 'intermingle'), (5, 'intermit'), (5, 'intermittent'), (5, 'internist'), (5, 'interpiece'), (5, 'interplant'), (5, 'interpledge'), (5, 'interplight'), (5, 'interpoint'), (5, 'interpret'), (5, 'interpunct'), (5, 'interreign'), (5, 'interrenal'), (5, 'interright'), (5, 'interriven'), (5, 'interscene'), (5, 'interscience'), (5, 'intersect'), (5, 'interset'), (5, 'interthing'), (5, 'intertie'), (5, 'intervenant'), (5, 'intervene'), (5, 'intervener'), (5, 'intervenient'), (5, 'intervert'), (5, 'interview'), (5, 'interviewee'), (5, 'interviewer'), (5, 'intervisit'), (5, 'interwind'), (5, 'intestinal'), (5, 'intestine'), (5, 'intextine'), (5, 'inthrallment'), (5, 'intolerant'), (5, 'intonement'), (5, 'intransient'), (5, 'intruding'), (5, 'intuent'), (5, 'inturning'), (5, 'investment'), (5, 'involvent'), (5, 'irresilient'), (5, 'iteming'), (6, 'iceblink'), (6, 'icterine'), (6, 'icterogenic'), (6, 'idealist'), (6, 'idlement'), (6, 'idyllian'), (6, 'ignescent'), (6, 'illeist'), (6, 'illicit'), (6, 'illipene'), (6, 'imbellious'), (6, 'immergent'), (6, 'impalement'), (6, 'impatient'), (6, 'impediment'), (6, 'impeding'), (6, 'impeller'), (6, 'impendent'), (6, 'impending'), (6, 'impenitent'), (6, 'imperent'), (6, 'imperilment'), (6, 'impertinent'), (6, 'implement'), (6, 'impling') ...

# %% [markdown]
# ## working with own dictionary

# %%
mistake = "पात"
dictionary = ['पातलो', 'पात', 'पत्रु', 'पात्र']

for word in dictionary:
    ed = nltk.edit_distance(mistake, dictionary)
    print(word, ed)
# Out:
# पातलो 4
# पात 4
# पत्रु 4
# पात्र 4

# %%
mistake = "पात"
words = ['पातलो', 'पात', 'पत्रु', 'पात्र']
for word in words:
    ed = nltk.edit_distance(mistake, word)
    print(word, ed)
# Out:
# पातलो 2
# पात 0
# पत्रु 4
# पात्र 2
